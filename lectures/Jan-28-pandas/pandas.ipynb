# %% [markdown]
# # Pandas
#
# https://pandas.pydata.org/
#
# An intro to Pandas: https://www.learndatasci.com/tutorials/python-pandas-tutorial-complete-introduction-for-beginners/
#
# ![](images/csv-sheet.png)

# %% [markdown]
# # Series and DataFrames
#
# ![](images/series-dataframe.png)

# %%
from sklearn import datasets

diabetes = datasets.load_diabetes()

features = "age sex bmi bp tc ldl hdl tch ltg glu".split()

features
# Out:
# ['age', 'sex', 'bmi', 'bp', 'tc', 'ldl', 'hdl', 'tch', 'ltg', 'glu']

# %%
dir(diabetes)
# Out:
# ['DESCR',
#  'data',
#  'data_filename',
#  'feature_names',
#  'frame',
#  'target',
#  'target_filename']

# %%
# Each row of diabetes.data is all 10 measurements 
# for a single patient.
diabetes.data.shape
# Out:
# (442, 10)

# %%
diabetes.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990842, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06832974, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286377, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04687948,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452837, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00421986,  0.00306441]])

# %%
import pandas as pd

df = pd.DataFrame(diabetes.data, columns=features)

df
# Out:
#           age       sex       bmi        bp        tc       ldl       hdl  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#           tch       ltg       glu
# 0   -0.002592  0.019908 -0.017646
# ...

# %%
# columns
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 'tc', 'ldl', 'hdl', 'tch', 'ltg', 'glu'], dtype='object')

# %%
# rows
df.index
# Out:
# RangeIndex(start=0, stop=442, step=1)

# %%
df.shape
# Out:
# (442, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   tc      442 non-null    float64
#  5   ldl     442 non-null    float64
#  6   hdl     442 non-null    float64
#  7   tch     442 non-null    float64
#  8   ltg     442 non-null    float64
#  9   glu     442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
df.head(4)
# Out:
#         age       sex       bmi        bp        tc       ldl       hdl  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
#
#         tch       ltg       glu
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362

# %%
df.tail(3)
# Out:
#           age       sex       bmi        bp        tc       ldl       hdl  \
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#           tch       ltg       glu
# 439 -0.011080 -0.046879  0.015491
# 440  0.026560  0.044528 -0.025930
# 441 -0.039493 -0.004220  0.003064

# %% [markdown]
# # Work with a column

# %%
df['bmi']
# Out:
# 0      0.061696
# 1     -0.051474
# 2      0.044451
# 3     -0.011595
# 4     -0.036385
#          ...
# 437    0.019662
# 438   -0.015906
# 439   -0.015906
# 440    0.039062
# 441   -0.073030
# Name: bmi, Length: 442, dtype: float64

# %%
type(df), type(df['bmi'])
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
df['bmi'][3]
# Out:
# -0.0115950145052127

# %% [markdown]
# # <font color=red>Quiz 1</font>
#
# How would you get a list of **hdl** values for **patients 430-435**?
#
#     A) df[6][430:436]
#     B) df['hdl'][430:436]
#     C) df['hdl'][430:435]

# %% [markdown]
# # Work with multiple columns

# %%
df2 = df[['bmi', 'age']]

df2.head()
# Out:
#         bmi       age
# 0  0.061696  0.038076
# 1 -0.051474 -0.001882
# 2  0.044451  0.085299
# 3 -0.011595 -0.089063
# 4 -0.036385  0.005383

# %%
df2['bmi'][1:4]
# Out:
# 1   -0.051474
# 2    0.044451
# 3   -0.011595
# Name: bmi, dtype: float64

# %% [markdown]
# # Single column DataFrame

# %%
df2 = df[['age']]

df2.head()
# Out:
#         age
# 0  0.038076
# 1 -0.001882
# 2  0.085299
# 3 -0.089063
# 4  0.005383

# %% [markdown]
# # Add column

# %%
import numpy as np

df['new'] = np.random.random(442)

df.head()
# Out:
#         age       sex       bmi        bp        tc       ldl       hdl  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#         tch       ltg       glu       new
# 0 -0.002592  0.019908 -0.017646  0.998411
# 1 -0.039493 -0.068330 -0.092204  0.201684
# 2 -0.002592  0.002864 -0.025930  0.366920
# 3  0.034309  0.022692 -0.009362  0.226971
# 4 -0.002592 -0.031991 -0.046641  0.402926

# %% [markdown]
# # Remove column

# %%
del df['new']

df
# Out:
#           age       sex       bmi        bp        tc       ldl       hdl  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#           tch       ltg       glu
# 0   -0.002592  0.019908 -0.017646
# ...

# %% [markdown]
# # Take a minute to collect your thoughts...

# %% [markdown]
# # Is the presentation clear?
#
# ![](../../images/zoom-yes-no.png)

# %% [markdown]
# # Do you want me to go slower or faster?
#
# ![](../../images/zoom-slower-faster.png)

# %% [markdown]
# # iloc: row index

# %%
df.head()
# Out:
#         age       sex       bmi        bp        tc       ldl       hdl  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#         tch       ltg       glu
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
df.iloc[3]
# Out:
# age   -0.089063
# sex   -0.044642
# bmi   -0.011595
# bp    -0.036656
# tc     0.012191
# ldl    0.024991
# hdl   -0.036038
# tch    0.034309
# ltg    0.022692
# glu   -0.009362
# Name: 3, dtype: float64

# %% [markdown]
# # iloc: row slice

# %%
df.head()
# Out:
#         age       sex       bmi        bp        tc       ldl       hdl  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#         tch       ltg       glu
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
df.iloc[3:5]
# Out:
#         age       sex       bmi        bp        tc       ldl       hdl  \
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#         tch       ltg       glu
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %% [markdown]
# # iloc: rows, cols

# %%
df.head()
# Out:
#         age       sex       bmi        bp        tc       ldl       hdl  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#         tch       ltg       glu
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
df.iloc[3,2]
# Out:
# -0.0115950145052127

# %%
df.iloc[3:5, [0,2]]
# Out:
#         age       bmi
# 3 -0.089063 -0.011595
# 4  0.005383 -0.036385

# %% [markdown]
# # <font color=red>Quiz 2</font>
#
# How would you use *iloc* to get a list of **ldl** and **hdl** values for **patients 430-435**?
#
#     A) df.iloc[6:7,430:436]
#     B) df.iloc[6:8,430:436]
#     C) df.iloc[5:7,430:436]
#     D) df.iloc[430:436,5:7]

# %%
df.head()
# Out:
#         age       sex       bmi        bp        tc       ldl       hdl  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#         tch       ltg       glu
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %% [markdown]
# # loc: row, col names

# %%
df.head()
# Out:
#         age       sex       bmi        bp        tc       ldl       hdl  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#         tch       ltg       glu
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
df.loc[3:5, ['age', 'bmi']]
# Out:
#         age       bmi
# 3 -0.089063 -0.011595
# 4  0.005383 -0.036385
# 5 -0.092695 -0.040696

# %% [markdown]
# ### <font color=red>!!! loc ranges start:stop INCLUDE stop.</font>

# %% [markdown]
# # loc: col ranges by name

# %%
df.head()
# Out:
#         age       sex       bmi        bp        tc       ldl       hdl  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#         tch       ltg       glu
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
df.loc[3:5, 'age':'bmi']
# Out:
#         age       sex       bmi
# 3 -0.089063 -0.044642 -0.011595
# 4  0.005383 -0.044642 -0.036385
# 5 -0.092695 -0.044642 -0.040696

# %% [markdown]
# # <font color=red>Quiz 3</font>
#
# How would you use *loc* to get a list of **ldl** and **hdl** values for **patients 430-435**?
#
#     A) df.loc[430:436,5:7]
#     B) df.loc[430:436,['ldl':'hdl']]
#     C) df.loc[430:436,['ldl':'tch']]

# %%
df.head()
# Out:
#         age       sex       bmi        bp        tc       ldl       hdl  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#         tch       ltg       glu
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %% [markdown]
# # Noninteger row indexes

# %%
# I've used a list comprehension here.
# Don't worry if it doesn't make sense.
df.index = [f"Patient {i}" for i in range(442)]

df
# Out:
#                   age       sex       bmi        bp        tc       ldl  \
# Patient 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821
# Patient 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163
# Patient 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194
# Patient 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991
# Patient 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596
# ...               ...       ...       ...       ...       ...       ...
# Patient 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566
# Patient 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165
# Patient 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840
# Patient 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283
# Patient 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809
#
#                   hdl       tch       ltg       glu
# ...

# %%
df.index[0], df.index[1]
# Out:
# ('Patient 0', 'Patient 1')

# %% [markdown]
# # Noninteger row indexes

# %%
df.head()
# Out:
#                 age       sex       bmi        bp        tc       ldl  \
# Patient 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821
# Patient 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163
# Patient 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194
# Patient 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991
# Patient 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596
#
#                 hdl       tch       ltg       glu
# Patient 0 -0.043401 -0.002592  0.019908 -0.017646
# Patient 1  0.074412 -0.039493 -0.068330 -0.092204
# Patient 2 -0.032356 -0.002592  0.002864 -0.025930
# Patient 3 -0.036038  0.034309  0.022692 -0.009362
# Patient 4  0.008142 -0.002592 -0.031991 -0.046641

# %%
df.loc['Patient 2':'Patient 4', 'age':'bmi']
# Out:
#                 age       sex       bmi
# Patient 2  0.085299  0.050680  0.044451
# Patient 3 -0.089063 -0.044642 -0.011595
# Patient 4  0.005383 -0.044642 -0.036385

# %% [markdown]
# # Select rows

# %%
df.head()
# Out:
#                 age       sex       bmi        bp        tc       ldl  \
# Patient 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821
# Patient 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163
# Patient 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194
# Patient 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991
# Patient 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596
#
#                 hdl       tch       ltg       glu
# Patient 0 -0.043401 -0.002592  0.019908 -0.017646
# Patient 1  0.074412 -0.039493 -0.068330 -0.092204
# Patient 2 -0.032356 -0.002592  0.002864 -0.025930
# Patient 3 -0.036038  0.034309  0.022692 -0.009362
# Patient 4  0.008142 -0.002592 -0.031991 -0.046641

# %%
males = df[df['sex'] < 0]

males.iloc[:5]
# Out:
#                 age       sex       bmi        bp        tc       ldl  \
# Patient 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163
# Patient 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991
# Patient 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596
# Patient 5 -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288
# Patient 9 -0.070900 -0.044642  0.039062 -0.033214 -0.012577 -0.034508
#
#                 hdl       tch       ltg       glu
# Patient 1  0.074412 -0.039493 -0.068330 -0.092204
# Patient 3 -0.036038  0.034309  0.022692 -0.009362
# Patient 4  0.008142 -0.002592 -0.031991 -0.046641
# Patient 5  0.041277 -0.076395 -0.041180 -0.096346
# Patient 9 -0.024993 -0.002592  0.067736 -0.013504

# %% [markdown]
# # Select rows

# %%
male_and_child = df[(df['sex'] < 0) & (df['age'] < 0)]

male_and_child.iloc[:5]
# Out:
#                  age       sex       bmi        bp        tc       ldl  \
# Patient 1  -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163
# Patient 3  -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991
# Patient 5  -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288
# Patient 9  -0.070900 -0.044642  0.039062 -0.033214 -0.012577 -0.034508
# Patient 10 -0.096328 -0.044642 -0.083808  0.008101 -0.103389 -0.090561
#
#                  hdl       tch       ltg       glu
# Patient 1   0.074412 -0.039493 -0.068330 -0.092204
# Patient 3  -0.036038  0.034309  0.022692 -0.009362
# Patient 5   0.041277 -0.076395 -0.041180 -0.096346
# Patient 9  -0.024993 -0.002592  0.067736 -0.013504
# Patient 10 -0.013948 -0.076395 -0.062913 -0.034215

# %%
male_or_child = df[(df['sex'] < 0) | (df['age'] < 0)]

male_or_child.iloc[:5]
# Out:
#                 age       sex       bmi        bp        tc       ldl  \
# Patient 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163
# Patient 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991
# Patient 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596
# Patient 5 -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288
# Patient 6 -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800
#
#                 hdl       tch       ltg       glu
# Patient 1  0.074412 -0.039493 -0.068330 -0.092204
# Patient 3 -0.036038  0.034309  0.022692 -0.009362
# Patient 4  0.008142 -0.002592 -0.031991 -0.046641
# Patient 5  0.041277 -0.076395 -0.041180 -0.096346
# Patient 6  0.000779 -0.039493 -0.062913 -0.038357

# %% [markdown]
# # <font color=red>Quiz 4</font>
#
# How would you get all the data for patients with **bp > 0**?
#
#     A) df[:,df['bp'] > 0]
#     B) df[df['bp'] > 0,:]
#     C) df['bp' > 0]
#     D) df[df['bp'] > 0]

# %%
df.head()
# Out:
#                 age       sex       bmi        bp        tc       ldl  \
# Patient 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821
# Patient 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163
# Patient 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194
# Patient 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991
# Patient 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596
#
#                 hdl       tch       ltg       glu
# Patient 0 -0.043401 -0.002592  0.019908 -0.017646
# Patient 1  0.074412 -0.039493 -0.068330 -0.092204
# Patient 2 -0.032356 -0.002592  0.002864 -0.025930
# Patient 3 -0.036038  0.034309  0.022692 -0.009362
# Patient 4  0.008142 -0.002592 -0.031991 -0.046641

# %% [markdown]
# # Take a minute to collect your thoughts...

# %% [markdown]
# # Is the presentation clear?
#
# ![](../../images/zoom-yes-no.png)

# %% [markdown]
# # Do you want me to go slower or faster?
#
# ![](../../images/zoom-slower-faster.png)

# %% [markdown]
# # Nonnumeric columns

# %%
df.head()
# Out:
#                 age       sex       bmi        bp        tc       ldl  \
# Patient 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821
# Patient 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163
# Patient 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194
# Patient 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991
# Patient 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596
#
#                 hdl       tch       ltg       glu
# Patient 0 -0.043401 -0.002592  0.019908 -0.017646
# Patient 1  0.074412 -0.039493 -0.068330 -0.092204
# Patient 2 -0.032356 -0.002592  0.002864 -0.025930
# Patient 3 -0.036038  0.034309  0.022692 -0.009362
# Patient 4  0.008142 -0.002592 -0.031991 -0.046641

# %%
mf = []
for sex in df['sex']:
    if sex < 0:
        mf.append('M')
    else:
        mf.append('F')

df['sex'] = mf

df.head()
# Out:
#                 age sex       bmi        bp        tc       ldl       hdl  \
# Patient 0  0.038076   F  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# Patient 1 -0.001882   M -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# Patient 2  0.085299   F  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# Patient 3 -0.089063   M -0.011595 -0.036656  0.012191  0.024991 -0.036038
# Patient 4  0.005383   M -0.036385  0.021872  0.003935  0.015596  0.008142
#
#                 tch       ltg       glu
# Patient 0 -0.002592  0.019908 -0.017646
# Patient 1 -0.039493 -0.068330 -0.092204
# Patient 2 -0.002592  0.002864 -0.025930
# Patient 3  0.034309  0.022692 -0.009362
# Patient 4 -0.002592 -0.031991 -0.046641

# %% [markdown]
# # Extract data as NumPy array

# %%
df
# Out:
#                   age sex       bmi        bp        tc       ldl       hdl  \
# Patient 0    0.038076   F  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# Patient 1   -0.001882   M -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# Patient 2    0.085299   F  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# Patient 3   -0.089063   M -0.011595 -0.036656  0.012191  0.024991 -0.036038
# Patient 4    0.005383   M -0.036385  0.021872  0.003935  0.015596  0.008142
# ...               ...  ..       ...       ...       ...       ...       ...
# Patient 437  0.041708   F  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# Patient 438 -0.005515   F -0.015906 -0.067642  0.049341  0.079165 -0.028674
# Patient 439  0.041708   F -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# Patient 440 -0.045472   M  0.039062  0.001215  0.016318  0.015283 -0.028674
# Patient 441 -0.045472   M -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#                   tch       ltg       glu
# ...

# %%
bmi = df['bmi'].to_numpy()

type(bmi), bmi.shape
# Out:
# (numpy.ndarray, (442,))

# %% [markdown]
# # Sorting

# %%
df.head()
# Out:
#                 age sex       bmi        bp        tc       ldl       hdl  \
# Patient 0  0.038076   F  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# Patient 1 -0.001882   M -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# Patient 2  0.085299   F  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# Patient 3 -0.089063   M -0.011595 -0.036656  0.012191  0.024991 -0.036038
# Patient 4  0.005383   M -0.036385  0.021872  0.003935  0.015596  0.008142
#
#                 tch       ltg       glu
# Patient 0 -0.002592  0.019908 -0.017646
# Patient 1 -0.039493 -0.068330 -0.092204
# Patient 2 -0.002592  0.002864 -0.025930
# Patient 3  0.034309  0.022692 -0.009362
# Patient 4 -0.002592 -0.031991 -0.046641

# %%
# !!! df is unchanged
df2 = df.sort_values(by='age')

df2
# Out:
#                   age sex       bmi        bp        tc       ldl       hdl  \
# Patient 26  -0.107226   M -0.077342 -0.026328 -0.089630 -0.096198  0.026550
# Patient 374 -0.107226   M -0.034229 -0.067642 -0.063487 -0.070520  0.008142
# Patient 344 -0.107226   M -0.011595 -0.040099  0.049341  0.064447 -0.013948
# Patient 79  -0.103593   M -0.037463 -0.026328  0.002559  0.019980  0.011824
# Patient 226 -0.103593   F -0.046085 -0.026328 -0.024960 -0.024800  0.030232
# ...               ...  ..       ...       ...       ...       ...       ...
# Patient 211  0.092564   M  0.036907  0.021872 -0.024960 -0.016658  0.000779
# Patient 311  0.096197   M  0.040140 -0.057314  0.045213  0.060690 -0.021311
# Patient 321  0.096197   M  0.051996  0.079254  0.054845  0.036577 -0.076536
# Patient 402  0.110727   F -0.033151 -0.022885 -0.004321  0.020293 -0.061809
# Patient 204  0.110727   F  0.006728  0.028758 -0.027712 -0.007264 -0.047082
#
#                   tch       ltg       glu
# ...

# %% [markdown]
# # Altering originial DataFrame

# %%
df.head()
# Out:
#                 age sex       bmi        bp        tc       ldl       hdl  \
# Patient 0  0.038076   F  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# Patient 1 -0.001882   M -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# Patient 2  0.085299   F  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# Patient 3 -0.089063   M -0.011595 -0.036656  0.012191  0.024991 -0.036038
# Patient 4  0.005383   M -0.036385  0.021872  0.003935  0.015596  0.008142
#
#                 tch       ltg       glu
# Patient 0 -0.002592  0.019908 -0.017646
# Patient 1 -0.039493 -0.068330 -0.092204
# Patient 2 -0.002592  0.002864 -0.025930
# Patient 3  0.034309  0.022692 -0.009362
# Patient 4 -0.002592 -0.031991 -0.046641

# %%
df.sort_values(by='age', inplace=True)

df
# Out:
#                   age sex       bmi        bp        tc       ldl       hdl  \
# Patient 26  -0.107226   M -0.077342 -0.026328 -0.089630 -0.096198  0.026550
# Patient 374 -0.107226   M -0.034229 -0.067642 -0.063487 -0.070520  0.008142
# Patient 344 -0.107226   M -0.011595 -0.040099  0.049341  0.064447 -0.013948
# Patient 79  -0.103593   M -0.037463 -0.026328  0.002559  0.019980  0.011824
# Patient 226 -0.103593   F -0.046085 -0.026328 -0.024960 -0.024800  0.030232
# ...               ...  ..       ...       ...       ...       ...       ...
# Patient 211  0.092564   M  0.036907  0.021872 -0.024960 -0.016658  0.000779
# Patient 311  0.096197   M  0.040140 -0.057314  0.045213  0.060690 -0.021311
# Patient 321  0.096197   M  0.051996  0.079254  0.054845  0.036577 -0.076536
# Patient 402  0.110727   F -0.033151 -0.022885 -0.004321  0.020293 -0.061809
# Patient 204  0.110727   F  0.006728  0.028758 -0.027712 -0.007264 -0.047082
#
#                   tch       ltg       glu
# ...

# %% [markdown]
# # Change a single cell
#
# Note: There are other ways to do this (e.g. *apply*).

# %%
df.head()
# Out:
#                   age sex       bmi        bp        tc       ldl       hdl  \
# Patient 26  -0.107226   M -0.077342 -0.026328 -0.089630 -0.096198  0.026550
# Patient 374 -0.107226   M -0.034229 -0.067642 -0.063487 -0.070520  0.008142
# Patient 344 -0.107226   M -0.011595 -0.040099  0.049341  0.064447 -0.013948
# Patient 79  -0.103593   M -0.037463 -0.026328  0.002559  0.019980  0.011824
# Patient 226 -0.103593   F -0.046085 -0.026328 -0.024960 -0.024800  0.030232
#
#                   tch       ltg       glu
# Patient 26  -0.076395 -0.042572 -0.005220
# Patient 374 -0.039493 -0.000609 -0.079778
# Patient 344  0.034309  0.007027 -0.030072
# Patient 79  -0.002592 -0.068330 -0.025930
# Patient 226 -0.039493 -0.039810 -0.054925

# %%
df['glu'][0] = 0
# Out:
# <ipython-input-51-deabf2835cf6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['glu'][0] = 0

# %%
glu = df['glu'].to_numpy()
glu[0] = 0
df['glu'] = glu

df.head()
# Out:
#                   age sex       bmi        bp        tc       ldl       hdl  \
# Patient 26  -0.107226   M -0.077342 -0.026328 -0.089630 -0.096198  0.026550
# Patient 374 -0.107226   M -0.034229 -0.067642 -0.063487 -0.070520  0.008142
# Patient 344 -0.107226   M -0.011595 -0.040099  0.049341  0.064447 -0.013948
# Patient 79  -0.103593   M -0.037463 -0.026328  0.002559  0.019980  0.011824
# Patient 226 -0.103593   F -0.046085 -0.026328 -0.024960 -0.024800  0.030232
#
#                   tch       ltg       glu
# Patient 26  -0.076395 -0.042572  0.000000
# Patient 374 -0.039493 -0.000609 -0.079778
# Patient 344  0.034309  0.007027 -0.030072
# Patient 79  -0.002592 -0.068330 -0.025930
# Patient 226 -0.039493 -0.039810 -0.054925

# %% [markdown]
# # <font color=red>Exercise</font>
#
# Change all the glu values to True or False based on whether or not they are >= 0.

# %%
df['glu'] = ...

df.head()

# %% [markdown]
# # Take a minute to collect your thoughts...

# %% [markdown]
# # Is the presentation clear?
#
# ![](../../images/zoom-yes-no.png)

# %% [markdown]
# # Do you want me to go slower or faster?
#
# ![](../../images/zoom-slower-faster.png)

# %% [markdown]
# # Visualization

# %%
df.head(10).style\
    .background_gradient(cmap='cool')
# Out:
# <style  type="text/css" >
# #T_1dcd6fda_543e_11eb_a873_acde48001122row0_col0,#T_1dcd6fda_543e_11eb_a873_acde48001122row0_col5,#T_1dcd6fda_543e_11eb_a873_acde48001122row0_col7,#T_1dcd6fda_543e_11eb_a873_acde48001122row1_col0,#T_1dcd6fda_543e_11eb_a873_acde48001122row1_col9,#T_1dcd6fda_543e_11eb_a873_acde48001122row2_col0,#T_1dcd6fda_543e_11eb_a873_acde48001122row5_col6,#T_1dcd6fda_543e_11eb_a873_acde48001122row5_col8,#T_1dcd6fda_543e_11eb_a873_acde48001122row6_col3,#T_1dcd6fda_543e_11eb_a873_acde48001122row8_col2,#T_1dcd6fda_543e_11eb_a873_acde48001122row8_col4,#T_1dcd6fda_543e_11eb_a873_acde48001122row8_col7{
#             background-color:  #00ffff;
#             color:  #000000;
#         }#T_1dcd6fda_543e_11eb_a873_acde48001122row0_col2{
#             background-color:  #16e9ff;
#             color:  #000000;
# ...

# %% [markdown]
# # Visualization

# %%
df.head(10).style\
    .background_gradient(cmap='bone', low=-0.03, high=0.03, subset=['age', 'bmi', 'ldl'])\
    .highlight_max()
# Out:
# <style  type="text/css" >
# #T_2007d768_543e_11eb_a873_acde48001122row0_col0,#T_2007d768_543e_11eb_a873_acde48001122row0_col5,#T_2007d768_543e_11eb_a873_acde48001122row1_col0,#T_2007d768_543e_11eb_a873_acde48001122row2_col0,#T_2007d768_543e_11eb_a873_acde48001122row8_col2{
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }#T_2007d768_543e_11eb_a873_acde48001122row0_col2{
#             background-color:  #0d0d12;
#             color:  #f1f1f1;
#         }#T_2007d768_543e_11eb_a873_acde48001122row0_col9,#T_2007d768_543e_11eb_a873_acde48001122row2_col4,#T_2007d768_543e_11eb_a873_acde48001122row2_col7,#T_2007d768_543e_11eb_a873_acde48001122row2_col8,#T_2007d768_543e_11eb_a873_acde48001122row4_col6,#T_2007d768_543e_11eb_a873_acde48001122row8_col3{
#             background-color:  yellow;
#         }#T_2007d768_543e_11eb_a873_acde48001122row1_col2{
#             background-color:  #93acb3;
#             color:  #000000;
# ...

# %% [markdown]
# # Visualization

# %%
df.head(10).style\
    .bar(subset=['bmi'], color='red')
# Out:
# <style  type="text/css" >
# #T_20c86b72_543e_11eb_a873_acde48001122row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 9.0%, transparent 9.0%);
#         }#T_20c86b72_543e_11eb_a873_acde48001122row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 68.7%, transparent 68.7%);
#         }#T_20c86b72_543e_11eb_a873_acde48001122row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 100.0%, transparent 100.0%);
#         }#T_20c86b72_543e_11eb_a873_acde48001122row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 64.2%, transparent 64.2%);
#         }#T_20c86b72_543e_11eb_a873_acde48001122row4_col2{
#             width:  10em;
#              height:  80%;
# ...

# %% [markdown]
# # Pandas --> CSV spread sheet file

# %%
df.to_csv("diabetes.csv")

# %% [markdown]
# ### Open in spread sheet.
#
# ### <font color=red>Delete *bmi* values for the *2nd and 3rd patients*.</font>

# %% [markdown]
# # CSV file --> Pandas

# %%
df = pd.read_csv("diabetes.csv")

df.head()
# Out:
#     Unnamed: 0       age sex       bmi        bp        tc       ldl  \
# 0   Patient 26 -0.107226   M -0.077342 -0.026328 -0.089630 -0.096198
# 1  Patient 374 -0.107226   M       NaN -0.067642 -0.063487 -0.070520
# 2  Patient 344 -0.107226   M       NaN -0.040099  0.049341  0.064447
# 3   Patient 79 -0.103593   M -0.037463 -0.026328  0.002559  0.019980
# 4  Patient 226 -0.103593   F -0.046085 -0.026328 -0.024960 -0.024800
#
#         hdl       tch       ltg       glu
# 0  0.026550 -0.076395 -0.042572  0.000000
# 1  0.008142 -0.039493 -0.000609 -0.079778
# 2 -0.013948  0.034309  0.007027 -0.030072
# 3  0.011824 -0.002592 -0.068330 -0.025930
# 4  0.030232 -0.039493 -0.039810 -0.054925

# %%
df = pd.read_csv("diabetes.csv", index_col=0)

df.head()
# Out:
#                   age sex       bmi        bp        tc       ldl       hdl  \
# Patient 26  -0.107226   M -0.077342 -0.026328 -0.089630 -0.096198  0.026550
# Patient 374 -0.107226   M       NaN -0.067642 -0.063487 -0.070520  0.008142
# Patient 344 -0.107226   M       NaN -0.040099  0.049341  0.064447 -0.013948
# Patient 79  -0.103593   M -0.037463 -0.026328  0.002559  0.019980  0.011824
# Patient 226 -0.103593   F -0.046085 -0.026328 -0.024960 -0.024800  0.030232
#
#                   tch       ltg       glu
# Patient 26  -0.076395 -0.042572  0.000000
# Patient 374 -0.039493 -0.000609 -0.079778
# Patient 344  0.034309  0.007027 -0.030072
# Patient 79  -0.002592 -0.068330 -0.025930
# Patient 226 -0.039493 -0.039810 -0.054925

# %% [markdown]
# # Get rid of entries with missing values

# %%
df.head().style\
    .highlight_null()
# Out:
# <style  type="text/css" >
# #T_3eb8f642_543e_11eb_a873_acde48001122row1_col2,#T_3eb8f642_543e_11eb_a873_acde48001122row2_col2{
#             background-color:  red;
#         }</style><table id="T_3eb8f642_543e_11eb_a873_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >age</th>        <th class="col_heading level0 col1" >sex</th>        <th class="col_heading level0 col2" >bmi</th>        <th class="col_heading level0 col3" >bp</th>        <th class="col_heading level0 col4" >tc</th>        <th class="col_heading level0 col5" >ldl</th>        <th class="col_heading level0 col6" >hdl</th>        <th class="col_heading level0 col7" >tch</th>        <th class="col_heading level0 col8" >ltg</th>        <th class="col_heading level0 col9" >glu</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
df2 = df.dropna()

df2.head()
# Out:
#                   age sex       bmi        bp        tc       ldl       hdl  \
# Patient 26  -0.107226   M -0.077342 -0.026328 -0.089630 -0.096198  0.026550
# Patient 79  -0.103593   M -0.037463 -0.026328  0.002559  0.019980  0.011824
# Patient 226 -0.103593   F -0.046085 -0.026328 -0.024960 -0.024800  0.030232
# Patient 242 -0.103593   F -0.023451 -0.022885 -0.086878 -0.067701 -0.017629
# Patient 41  -0.099961   M -0.067641 -0.108957 -0.074494 -0.072712  0.015505
#
#                   tch       ltg       glu
# Patient 26  -0.076395 -0.042572  0.000000
# Patient 79  -0.002592 -0.068330 -0.025930
# Patient 226 -0.039493 -0.039810 -0.054925
# Patient 242 -0.039493 -0.078141 -0.071494
# Patient 41  -0.039493 -0.049868 -0.009362

# %% [markdown]
# # Fill in missing values

# %%
df.head().style\
    .highlight_null()
# Out:
# <style  type="text/css" >
# #T_48d22ec8_543e_11eb_a873_acde48001122row1_col2,#T_48d22ec8_543e_11eb_a873_acde48001122row2_col2{
#             background-color:  red;
#         }</style><table id="T_48d22ec8_543e_11eb_a873_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >age</th>        <th class="col_heading level0 col1" >sex</th>        <th class="col_heading level0 col2" >bmi</th>        <th class="col_heading level0 col3" >bp</th>        <th class="col_heading level0 col4" >tc</th>        <th class="col_heading level0 col5" >ldl</th>        <th class="col_heading level0 col6" >hdl</th>        <th class="col_heading level0 col7" >tch</th>        <th class="col_heading level0 col8" >ltg</th>        <th class="col_heading level0 col9" >glu</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
df.fillna(0, inplace=True)

df.head()
# Out:
#                   age sex       bmi        bp        tc       ldl       hdl  \
# Patient 26  -0.107226   M -0.077342 -0.026328 -0.089630 -0.096198  0.026550
# Patient 374 -0.107226   M  0.000000 -0.067642 -0.063487 -0.070520  0.008142
# Patient 344 -0.107226   M  0.000000 -0.040099  0.049341  0.064447 -0.013948
# Patient 79  -0.103593   M -0.037463 -0.026328  0.002559  0.019980  0.011824
# Patient 226 -0.103593   F -0.046085 -0.026328 -0.024960 -0.024800  0.030232
#
#                   tch       ltg       glu
# Patient 26  -0.076395 -0.042572  0.000000
# Patient 374 -0.039493 -0.000609 -0.079778
# Patient 344  0.034309  0.007027 -0.030072
# Patient 79  -0.002592 -0.068330 -0.025930
# Patient 226 -0.039493 -0.039810 -0.054925

# %% [markdown]
# # Concatenate DataFrames

# %%
df.shape
# Out:
# (442, 10)

# %%
df2 = df.append(df)

df2.shape
# Out:
# (884, 10)

# %% [markdown]
# # Remove duplicate entries

# %%
df2 = df2.drop_duplicates()

df2.shape
# Out:
# (442, 10)

# %% [markdown]
# # Stats

# %%
df.describe()
# Out:
#                 age         bmi            bp            tc           ldl  \
# count  4.420000e+02  442.000000  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -4.524946e-12    0.000104 -2.941177e-11 -6.130403e-18 -6.334842e-11
# std    4.761905e-02    0.047588  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01   -0.090275 -1.123996e-01 -1.267807e-01 -1.156131e-01
# 25%   -3.729927e-02   -0.034229 -3.665645e-02 -3.424784e-02 -3.035840e-02
# 50%    5.383060e-03   -0.006745 -5.670611e-03 -4.320866e-03 -3.819065e-03
# 75%    3.807591e-02    0.031248  3.564384e-02  2.835801e-02  2.984439e-02
# max    1.107267e-01    0.170555  1.320442e-01  1.539137e-01  1.987880e-01
#
#                 hdl           tch           ltg         glu
# count  4.420000e+02  4.420000e+02  4.420000e+02  442.000000
# mean   2.025152e-18 -1.809954e-11  2.262439e-12    0.000012
# std    4.761905e-02  4.761905e-02  4.761905e-02    0.047618
# min   -1.023071e-01 -7.639450e-02 -1.260974e-01   -0.137767
# ...

# %%
stats = df.describe()

stats.loc['mean','bmi']
# Out:
# 0.00010367440723981564

# %% [markdown]
# # Box plot

# %%
df.plot.box();

# %%
df[df['sex'] == 'F'].plot.box();

# %% [markdown]
# # Scatter plot

# %%
df.plot.scatter(x='age', y='bmi', c='ldl', cmap='jet');

# %% [markdown]
# # Bar plot

# %%
df.iloc[3,2:6].plot.bar();

# %%
df.iloc[:3,2:6].plot.bar();

# %% [markdown]
# # Histogram

# %%
df[['age', 'bmi']].plot.hist(bins=30, alpha=0.5);
